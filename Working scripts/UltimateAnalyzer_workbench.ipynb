# %%
#Importing the data extractor scripts
import sys
sys.path.insert(0, 'C:\\Users\\AU451FE\\OneDrive - EY\\Desktop\\Python\\HSreplay_scraper\\Scripts')

#import Extractors
#from UltimateExtractor import UltimateExtractor as UE

#Other useful packages
import time
import datetime
import pandas as pd
import numpy as np
import re #String search
import os

# %%
driver_path = 'C:/Users/AU451FE/OneDrive - EY/Desktop/Python/HSreplay_scraper/chromedriver'
deck_folder = 'C:/Users/AU451FE/OneDrive - EY/Desktop/Python/HSreplay_scraper/Data Frames'
analysis_path = 'C:/Users/AU451FE/OneDrive - EY/Desktop/Python/HSreplay_scraper/Data Frames/Analyzed'

# %%
#Employing the UltimateExtractor
#U = UE(driver_path, deck_folder)
#U.archetype_to_excel('MAGE', 'NO MINIon MAGE')

# %%
class UltimateAnalyzer:
    '''Text here
    '''
    def __init__(self, deck_folder):
        self.deck_folder = deck_folder
        self.analysis_path = analysis_path
        
    def percentage_to_float(self, number):
        try:
            number = number.str.strip('%').astype(float)/100 #For series
        except AttributeError:
            number = float(number.strip('%'))/100 #For single numbers
        
        return number
    
    def load_data(self, date, deck = None):
        '''Specify the date and deck name, then load the data from the data repository and return
            this data as either a data frame or a list of data frames, along with the deck keys in similar form.
            Lastly, return names of the decks in a list.
            
        :args:
        - date (str): A date from which to load the data.
        - deck (str): A deck for which to load the data for. If set to None, load the data for all decks.
        
        :usage:
            self.load_data('07-01', 'Rogue - Miracle Rogue')
            
        :returns:
        - data (pd.DataFrame or list): Either a pandas data frame (if deck is specified) or a list of these
            data frames, which contain all deck information.
        - data_keys (list): Either a list or a nested list of deck data sheet names, which serve
            to further extract data from individual sheets.
        - deck_names (string or list): Names of decks included in loaded data. Returned either as a string
            if a single deck is analyzed, or as a list, if multiple decks are analyzed.
        '''
        
        deck_folder_date = f'{self.deck_folder}/{date}'.replace('/', '\\') 
        file_paths = list()
        file_names = list()
        for (dirpath, dirnames, filenames) in os.walk(deck_folder_date):
            file_paths += [os.path.join(dirpath, file) for file in filenames]
            file_names += [re.search(f'(.+) ', file).group(1) for file in filenames]
            
        if deck != None:
            deck = deck.title()
            file_index = file_names.index(deck)
            data = pd.read_excel(file_paths[file_index], sheet_name = None)
            
            data_keys = list()
            [data_keys.append(key) for key in data]
            
            deck_names = deck
        else:
            data = []
            data_keys = []
            for file in file_paths:
                temp = pd.read_excel(file, sheet_name = None)
                data.append(temp)
                
                temp_keys = list()
                [temp_keys.append(key) for key in temp]
                data_keys.append(temp_keys)
                
                deck_names = file_names
                
        return data, data_keys, deck_names
    
    def analyze_deck_winrates(self, date, deck = None):
        '''Specify a date and a deck name for which to analyze win rates and return these as a pandas data frame.
            Said table contains the deck name and win rates both weighted and unweighted against all classes.
            
        :args:
        - date (str): The day for which to analyze the win rates.
        - deck (str): The deck for which to analyze the win rates.
        
        :usage:
            self.analyze_deck_winrates('07-01', 'Rogue - Miracle Rogue')
            
        :returns:
        - data_output (pd.DataFrame): A pandas data frame or a list of data frames,
            containing the deck name and win rates both weighted and unweighted against all classes.
            
        :note:
        - The deck name must be passed in a predefined format (e.g., Rogue - Miracle Rogue),
            apart from capitalization, which does need to be correct.
        '''
        data, data_keys, deck_names = self.load_data(date = date, deck = deck)

        if type(deck_names) == list:
            data_output = []
            deck_count = 0
            for d in data:
                overview = d.get('Overview')
                win_rates = overview.loc[:, 'Overall Winrate':'vs. Warlock'].apply(lambda x: self.percentage_to_float(x))
                sample_size = overview.loc[:, 'Sample Size']

                #Unweighted win rates
                WR_unweighted = win_rates.apply(np.mean, axis = 0)

                #Weighted win rates
                weights = sample_size/sum(sample_size)
                temp = win_rates.apply(lambda x: x*weights)
                WR_weighted = temp.apply(np.sum, axis = 0)
            
                deck_name = deck_names[deck_count]
                deck_count += 1
                temp = pd.DataFrame({'Deck Name': deck_name,
                                    'Unweighted Win Rate': WR_unweighted,
                                    'Weighted Win Rate' : WR_weighted})
                
                temp = temp.reset_index()
                temp = temp.set_index('Deck Name')
                temp = temp.rename(columns = {'index' : 'Versus'})                
                
                data_output.append(temp)
                
        else:
            overview = data.get('Overview')
            win_rates = overview.loc[:, 'Overall Winrate':'vs. Warlock'].apply(lambda x: self.percentage_to_float(x))
            sample_size = overview.loc[:, 'Sample Size']

            #Unweighted win rates
            WR_unweighted = win_rates.apply(np.mean, axis = 0)

            #Weighted win rates
            weights = sample_size/sum(sample_size)
            temp = win_rates.apply(lambda x: x*weights)
            WR_weighted = temp.apply(np.sum, axis = 0)
            
            temp = pd.DataFrame({'Deck Name': deck_names,
                                    'Unweighted Win Rate': WR_unweighted,
                                    'Weighted Win Rate' : WR_weighted})
            
            temp = temp.reset_index()
            temp = temp.set_index('Deck Name')
            data_output = temp.rename(columns = {'index' : 'Versus'})
        
        return data_output
    
    def deck_winrates_to_excel(self, date, deck = None):
        
        temp = self.analyze_deck_winrates(date = date, deck = deck)
        
        #Unweighted data frame
        data_u = pd.DataFrame()
        for i in range(len(temp)):
            one_deck = temp[i]
            pivot_deck = pd.pivot_table(data = one_deck, values = 'Unweighted Win Rate',
                                        index = 'Deck Name', columns = 'Versus')
            data_u = pd.concat([data_u, pivot_deck], axis = 0)
        
        path = f'{analysis_path}/Unweighted.xlsx'
        data_u.to_excel(path)
        
        #Weighted data frame
        data_w = pd.DataFrame()
        for i in range(len(temp)):
            one_deck = temp[i]
            pivot_deck = pd.pivot_table(data = one_deck, values = 'Weighted Win Rate',
                                        index = 'Deck Name', columns = 'Versus')
            data_w = pd.concat([data_w, pivot_deck], axis = 0)
        
        path = f'{analysis_path}/Weighted.xlsx'
        data_w.to_excel(path)
        
        return data_u, data_w
        
    def analyze_card_performance(self, date, deck = None):
        pass

# %%
UA = UltimateAnalyzer(deck_folder)
#data, data_keys, deck_names = UA.load_data(date = '07-09')
#data = UA.analyze_deck_winrates('07-09', deck = 'Rogue - Miracle Rogue')
#data = UA.deck_winrates_to_excel('07-09')

# %%
#data_output = UA.analyze_deck_winrates(date = '07-01')
data = UA.analyze_deck_winrates(date = '07-09')

# %%
UA.deck_winrates_to_excel('07-09')
# Out:
# (Versus                                  Overall Winrate  vs. Demon Hunter  \
#  Deck Name
#  Demonhunter - Big Demon Hunter                 0.556143          0.609429
#  Demonhunter - Deathrattle Demon Hunter         0.603056          0.580778
#  Demonhunter - Hybrid Demon Hunter              0.547500          0.477500
#  Demonhunter - Lifesteal Demon Hunter           0.485875          0.415750
#  Demonhunter - Midrange Demon Hunter            0.504500          0.474611
#  Demonhunter - Other                            0.514500          0.463500
#  Druid - Malygos Druid                          0.461333          0.574889
#  Druid - Miracle Druid                          0.374500          0.364643
#  Druid - Other                                  0.426125          0.586125
#  Druid - Primordial Druid                       0.569889          0.654778
#  Druid - Spell Druid                            0.577444          0.640278
#  Hunter - Face Hunter                           0.595389          0.609056
#  Hunter - Other                                 0.505750          0.545875
#  Hunter - Spell Hunter                          0.496000          0.466000
#  Mage - Freeze Mage                             0.438923          0.423769
#  Mage - No Minion Mage                          0.540778          0.499333
#  Mage - Other                                   0.446600          0.366867
#  Mage - Spell Damage Mage                       0.507000          0.450500
#  Paladin - Aggro Paladin                        0.512600          0.559100
#  Paladin - Menagerie Paladin                    0.565455          0.490182
#  Paladin - Other                                0.535667          0.530000
#  Paladin - Secret Libram Paladin                0.561000          0.558750
#  Paladin - Secret Paladin                       0.568083          0.569083
#  Paladin - Silver Hand Paladin                  0.463000          0.410000
#  Priest - Control Priest                        0.482118          0.489471
#  Priest - Corrupt Priest                        0.465143          0.441000
#  Priest - Menagerie Priest                      0.511222          0.510833
#  Priest - Other                                 0.450125          0.433125
#  Priest - Rally Priest                          0.466900          0.570000
#  Rogue - Miracle Rogue                          0.492500          0.474500
#  Rogue - Other                                  0.414000          0.424500
#  Rogue - Poison Rogue                           0.501750          0.486875
#  Rogue - Secret Rogue                           0.519083          0.534333
#  Shaman - Aggro Elemental Shaman                0.599389          0.544833
#  Shaman - Aggro Shaman                          0.592000          0.534000
#  Shaman - Elemental Shaman                      0.603556          0.602444
#  Shaman - Other                                 0.544833          0.477056
#  Warlock - Control Warlock                      0.537389          0.374833
#  Warlock - Delete Warlock                       0.448857          0.320000
#  Warlock - Other                                0.408333          0.324500
#  Warlock - Zoo Warlock                          0.489500          0.509333
#  Warrior - Control Warrior                      0.486389          0.396611
#  Warrior - Other                                0.477500          0.495250
#  Warrior - Rush Warrior                         0.591778          0.561778
#  Warrior - Taunt Warrior                        0.552000          0.419000
#
#  Versus                                  vs. Druid  vs. Hunter  vs. Mage  \
#  Deck Name
#  Demonhunter - Big Demon Hunter           0.477143    0.462714  0.654571
#  Demonhunter - Deathrattle Demon Hunter   0.454611    0.496556  0.690278
#  Demonhunter - Hybrid Demon Hunter        0.527500    0.570500  0.581000
#  Demonhunter - Lifesteal Demon Hunter     0.444875    0.526375  0.506563
#  Demonhunter - Midrange Demon Hunter      0.407444    0.468389  0.596833
#  Demonhunter - Other                      0.363000    0.384500  0.671000
#  Druid - Malygos Druid                    0.387000    0.476667  0.510667
#  Druid - Miracle Druid                    0.263571    0.289929  0.532571
#  Druid - Other                            0.479625    0.453750  0.378750
#  Druid - Primordial Druid                 0.529833    0.404944  0.613333
#  Druid - Spell Druid                      0.611667    0.582278  0.619833
#  Hunter - Face Hunter                     0.616278    0.567056  0.713444
#  Hunter - Other                           0.439625    0.471875  0.528000
#  Hunter - Spell Hunter                    0.479000    0.379000  0.491000
#  Mage - Freeze Mage                       0.494923    0.329077  0.370462
#  Mage - No Minion Mage                    0.504556    0.422444  0.617333
#  Mage - Other                             0.442067    0.352800  0.475867
#  Mage - Spell Damage Mage                 0.549700    0.439800  0.537200
#  Paladin - Aggro Paladin                  0.529400    0.458000  0.557000
#  Paladin - Menagerie Paladin              0.542545    0.437091  0.672545
#  Paladin - Other                          0.510333    0.587000  0.575000
#  Paladin - Secret Libram Paladin          0.500500    0.643417  0.634250
#  Paladin - Secret Paladin                 0.599250    0.544000  0.647250
#  Paladin - Silver Hand Paladin            0.500000    0.403000  0.495000
#  Priest - Control Priest                  0.560235    0.624176  0.471118
#  Priest - Corrupt Priest                  0.395286    0.542286  0.410857
#  Priest - Menagerie Priest                0.556389    0.601167  0.443167
#  Priest - Other                           0.479625    0.551625  0.416875
#  Priest - Rally Priest                    0.520000    0.527800  0.409600
#  Rogue - Miracle Rogue                    0.483556    0.443056  0.560111
#  Rogue - Other                            0.369500    0.296250  0.492000
#  Rogue - Poison Rogue                     0.376125    0.338000  0.650875
#  Rogue - Secret Rogue                     0.453917    0.452417  0.550667
#  Shaman - Aggro Elemental Shaman          0.562056    0.478944  0.724222
#  Shaman - Aggro Shaman                    0.548000    0.477500  0.739500
#  Shaman - Elemental Shaman                0.601167    0.575222  0.681500
#  Shaman - Other                           0.583833    0.437056  0.652167
#  Warlock - Control Warlock                0.567444    0.462222  0.541333
#  Warlock - Delete Warlock                 0.456571    0.441857  0.412286
#  Warlock - Other                          0.376333    0.391833  0.411667
#  Warlock - Zoo Warlock                    0.618833    0.452000  0.541000
#  Warrior - Control Warrior                0.534056    0.558111  0.446333
#  Warrior - Other                          0.473750    0.539000  0.498750
#  Warrior - Rush Warrior                   0.545278    0.600278  0.655278
#  Warrior - Taunt Warrior                  0.660000    0.500000  0.549000
#
#  Versus                                  vs. Paladin  vs. Priest  vs. Rogue  \
#  Deck Name
#  Demonhunter - Big Demon Hunter             0.634857    0.535000   0.640714
#  Demonhunter - Deathrattle Demon Hunter     0.650556    0.604333   0.640333
#  Demonhunter - Hybrid Demon Hunter          0.480000    0.622000   0.587500
#  Demonhunter - Lifesteal Demon Hunter       0.323562    0.504125   0.545000
#  Demonhunter - Midrange Demon Hunter        0.442556    0.511222   0.503222
#  Demonhunter - Other                        0.468500    0.566000   0.567000
#  Druid - Malygos Druid                      0.412889    0.311111   0.525778
#  Druid - Miracle Druid                      0.341429    0.443929   0.398857
#  Druid - Other                              0.456625    0.365000   0.438625
#  Druid - Primordial Druid                   0.586000    0.589056   0.597278
#  Druid - Spell Druid                        0.614944    0.533167   0.658167
#  Hunter - Face Hunter                       0.593778    0.479944   0.671167
#  Hunter - Other                             0.509125    0.556000   0.505750
#  Hunter - Spell Hunter                      0.547000    0.604000   0.462000
#  Mage - Freeze Mage                         0.589308    0.558846   0.543000
#  Mage - No Minion Mage                      0.513611    0.658111   0.578611
#  Mage - Other                               0.513067    0.557133   0.496933
#  Mage - Spell Damage Mage                   0.529400    0.604600   0.601300
#  Paladin - Aggro Paladin                    0.550600    0.470300   0.471000
#  Paladin - Menagerie Paladin                0.588000    0.693364   0.587091
#  Paladin - Other                            0.553000    0.505000   0.569333
#  Paladin - Secret Libram Paladin            0.547833    0.510667   0.612500
#  Paladin - Secret Paladin                   0.568917    0.569000   0.612750
#  Paladin - Silver Hand Paladin              0.517000    0.706000   0.560000
#  Priest - Control Priest                    0.534471    0.446529   0.486176
#  Priest - Corrupt Priest                    0.513857    0.532714   0.524857
#  Priest - Menagerie Priest                  0.540500    0.525278   0.562778
#  Priest - Other                             0.503750    0.455625   0.470500
#  Priest - Rally Priest                      0.496300    0.536700   0.470100
#  Rogue - Miracle Rogue                      0.515944    0.494056   0.539000
#  Rogue - Other                              0.297250    0.413250   0.552000
#  Rogue - Poison Rogue                       0.264500    0.533875   0.610750
#  Rogue - Secret Rogue                       0.670083    0.609167   0.506250
#  Shaman - Aggro Elemental Shaman            0.582056    0.662056   0.638056
#  Shaman - Aggro Shaman                      0.526500    0.664500   0.626500
#  Shaman - Elemental Shaman                  0.670333    0.597000   0.661611
#  Shaman - Other                             0.507944    0.564667   0.629056
#  Warlock - Control Warlock                  0.636167    0.735167   0.558056
#  Warlock - Delete Warlock                   0.495143    0.536429   0.468286
#  Warlock - Other                            0.406333    0.504667   0.473167
#  Warlock - Zoo Warlock                      0.518333    0.487333   0.607833
#  Warrior - Control Warrior                  0.525444    0.440389   0.576222
#  Warrior - Other                            0.487000    0.443250   0.585250
#  Warrior - Rush Warrior                     0.635333    0.496833   0.683611
#  Warrior - Taunt Warrior                    0.375000    0.475000   0.765000
#
#  Versus                                  vs. Shaman  vs. Warlock
#  Deck Name
#  Demonhunter - Big Demon Hunter            0.490143     0.621000
#  Demonhunter - Deathrattle Demon Hunter    0.561778     0.818056
#  Demonhunter - Hybrid Demon Hunter         0.509000     0.669000
#  Demonhunter - Lifesteal Demon Hunter      0.484063     0.601500
#  Demonhunter - Midrange Demon Hunter       0.440667     0.628778
#  Demonhunter - Other                       0.435500     0.685000
#  Druid - Malygos Druid                     0.504556     0.312778
#  Druid - Miracle Druid                     0.246571     0.460643
#  Druid - Other                             0.370875     0.366125
#  Druid - Primordial Druid                  0.512944     0.606222
#  Druid - Spell Druid                       0.502889     0.586444
#  Hunter - Face Hunter                      0.547778     0.669889
#  Hunter - Other                            0.432000     0.646250
#  Hunter - Spell Hunter                     0.456000     0.602000
#  Mage - Freeze Mage                        0.372385     0.432923
#  Mage - No Minion Mage                     0.442056     0.649778
#  Mage - Other                              0.316267     0.547667
#  Mage - Spell Damage Mage                  0.407200     0.585600
#  Paladin - Aggro Paladin                   0.485100     0.556900
#  Paladin - Menagerie Paladin               0.452818     0.649182
#  Paladin - Other                           0.512667     0.544333
#  Paladin - Secret Libram Paladin           0.545750     0.487333
#  Paladin - Secret Paladin                  0.446500     0.605417
#  Paladin - Silver Hand Paladin             0.263000     0.480000
#  Priest - Control Priest                   0.480176     0.260412
#  Priest - Corrupt Priest                   0.415857     0.421571
#  Priest - Menagerie Priest                 0.473556     0.362667
#  Priest - Other                            0.437375     0.347375
#  Priest - Rally Priest                     0.369600     0.325900
#  Rogue - Miracle Rogue                     0.456722     0.583722
#  Rogue - Other                             0.337500     0.540500
#  Rogue - Poison Rogue                      0.425500     0.750750
#  Rogue - Secret Rogue                      0.420667     0.533167
#  Shaman - Aggro Elemental Shaman           0.536722     0.778611
#  Shaman - Aggro Shaman                     0.501500     0.811500
#  Shaman - Elemental Shaman                 0.551944     0.640722
#  Shaman - Other                            0.486389     0.645167
#  Warlock - Control Warlock                 0.436111     0.509056
#  Warlock - Delete Warlock                  0.433429     0.450429
#  Warlock - Other                           0.313667     0.419667
#  Warlock - Zoo Warlock                     0.401000     0.400667
#  Warrior - Control Warrior                 0.535778     0.357333
#  Warrior - Other                           0.455500     0.386750
#  Warrior - Rush Warrior                    0.642111     0.531389
#  Warrior - Taunt Warrior                   0.610000     0.533000  ,
#  Versus                                  Overall Winrate  vs. Demon Hunter  \
#  Deck Name
#  Demonhunter - Big Demon Hunter                 0.579089          0.598518
#  Demonhunter - Deathrattle Demon Hunter         0.602361          0.584289
#  Demonhunter - Hybrid Demon Hunter              0.547241          0.472069
#  Demonhunter - Lifesteal Demon Hunter           0.487390          0.413735
#  Demonhunter - Midrange Demon Hunter            0.506779          0.485196
#  Demonhunter - Other                            0.542615          0.575631
#  Druid - Malygos Druid                          0.480970          0.607242
#  Druid - Miracle Druid                          0.366659          0.361971
#  Druid - Other                                  0.386229          0.564882
#  Druid - Primordial Druid                       0.566850          0.663994
#  Druid - Spell Druid                            0.579822          0.644564
#  Hunter - Face Hunter                           0.607746          0.618270
#  Hunter - Other                                 0.499132          0.492998
#  Hunter - Spell Hunter                          0.496000          0.466000
#  Mage - Freeze Mage                             0.438511          0.418870
#  Mage - No Minion Mage                          0.542181          0.509621
#  Mage - Other                                   0.449025          0.396958
#  Mage - Spell Damage Mage                       0.449089          0.425530
#  Paladin - Aggro Paladin                        0.430587          0.513691
#  Paladin - Menagerie Paladin                    0.569504          0.496280
#  Paladin - Other                                0.531795          0.559659
#  Paladin - Secret Libram Paladin                0.568068          0.571365
#  Paladin - Secret Paladin                       0.570978          0.517088
#  Paladin - Silver Hand Paladin                  0.463000          0.410000
#  Priest - Control Priest                        0.491463          0.505518
#  Priest - Corrupt Priest                        0.457189          0.464928
#  Priest - Menagerie Priest                      0.513072          0.513556
#  Priest - Other                                 0.422109          0.416882
#  Priest - Rally Priest                          0.466236          0.547870
#  Rogue - Miracle Rogue                          0.518059          0.504730
#  Rogue - Other                                  0.367869          0.405820
#  Rogue - Poison Rogue                           0.505209          0.517629
#  Rogue - Secret Rogue                           0.551839          0.576466
#  Shaman - Aggro Elemental Shaman                0.607789          0.556048
#  Shaman - Aggro Shaman                          0.592200          0.536200
#  Shaman - Elemental Shaman                      0.620538          0.606748
#  Shaman - Other                                 0.545746          0.477631
#  Warlock - Control Warlock                      0.532320          0.380291
#  Warlock - Delete Warlock                       0.462015          0.335229
#  Warlock - Other                                0.416328          0.282017
#  Warlock - Zoo Warlock                          0.504766          0.518694
#  Warrior - Control Warrior                      0.476902          0.397309
#  Warrior - Other                                0.524434          0.514104
#  Warrior - Rush Warrior                         0.586479          0.568728
#  Warrior - Taunt Warrior                        0.552000          0.419000
#
#  Versus                                  vs. Druid  vs. Hunter  vs. Mage  \
#  Deck Name
#  Demonhunter - Big Demon Hunter           0.474549    0.460642  0.701973
#  Demonhunter - Deathrattle Demon Hunter   0.454022    0.492750  0.687679
#  Demonhunter - Hybrid Demon Hunter        0.494655    0.553172  0.588759
#  Demonhunter - Lifesteal Demon Hunter     0.424712    0.533173  0.520606
#  Demonhunter - Midrange Demon Hunter      0.410724    0.461733  0.587850
#  Demonhunter - Other                      0.391446    0.445031  0.695477
#  Druid - Malygos Druid                    0.398827    0.466692  0.541524
#  Druid - Miracle Druid                    0.249022    0.276316  0.531229
#  Druid - Other                            0.427611    0.392945  0.353997
#  Druid - Primordial Druid                 0.518116    0.395231  0.616411
#  Druid - Spell Druid                      0.621589    0.585338  0.629147
#  Hunter - Face Hunter                     0.628482    0.576330  0.734561
#  Hunter - Other                           0.384990    0.422279  0.512683
#  Hunter - Spell Hunter                    0.479000    0.379000  0.491000
#  Mage - Freeze Mage                       0.495028    0.340332  0.383519
#  Mage - No Minion Mage                    0.504584    0.427165  0.610312
#  Mage - Other                             0.453380    0.381449  0.469837
#  Mage - Spell Damage Mage                 0.510385    0.390446  0.470897
#  Paladin - Aggro Paladin                  0.463459    0.418184  0.431463
#  Paladin - Menagerie Paladin              0.559226    0.459299  0.685951
#  Paladin - Other                          0.524455    0.538182  0.588830
#  Paladin - Secret Libram Paladin          0.513442    0.639464  0.645660
#  Paladin - Secret Paladin                 0.591066    0.539585  0.690003
#  Paladin - Silver Hand Paladin            0.500000    0.403000  0.495000
#  Priest - Control Priest                  0.556934    0.616569  0.470455
#  Priest - Corrupt Priest                  0.408585    0.505508  0.419662
#  Priest - Menagerie Priest                0.557324    0.599687  0.444522
#  Priest - Other                           0.464406    0.475477  0.405432
#  Priest - Rally Priest                    0.523070    0.538278  0.396637
#  Rogue - Miracle Rogue                    0.540358    0.486818  0.586885
#  Rogue - Other                            0.329240    0.265492  0.426503
#  Rogue - Poison Rogue                     0.372923    0.336441  0.661989
#  Rogue - Secret Rogue                     0.478237    0.479682  0.572827
#  Shaman - Aggro Elemental Shaman          0.554027    0.509795  0.735878
#  Shaman - Aggro Shaman                    0.556400    0.483400  0.736400
#  Shaman - Elemental Shaman                0.615850    0.593929  0.702371
#  Shaman - Other                           0.571916    0.436789  0.657648
#  Warlock - Control Warlock                0.555131    0.447059  0.554650
#  Warlock - Delete Warlock                 0.490340    0.490209  0.437213
#  Warlock - Other                          0.384911    0.395536  0.415219
#  Warlock - Zoo Warlock                    0.613694    0.436567  0.554986
#  Warrior - Control Warrior                0.512675    0.554760  0.433157
#  Warrior - Other                          0.526931    0.567162  0.547925
#  Warrior - Rush Warrior                   0.536012    0.579782  0.650173
#  Warrior - Taunt Warrior                  0.660000    0.500000  0.549000
#
#  Versus                                  vs. Paladin  vs. Priest  vs. Rogue  \
#  Deck Name
#  Demonhunter - Big Demon Hunter             0.693066    0.572436   0.627591
#  Demonhunter - Deathrattle Demon Hunter     0.658192    0.628570   0.624800
#  Demonhunter - Hybrid Demon Hunter          0.469655    0.644241   0.574828
#  Demonhunter - Lifesteal Demon Hunter       0.327238    0.514699   0.533919
#  Demonhunter - Midrange Demon Hunter        0.436183    0.519391   0.531263
#  Demonhunter - Other                        0.609077    0.489262   0.581554
#  Druid - Malygos Druid                      0.467557    0.323452   0.519047
#  Druid - Miracle Druid                      0.293172    0.448147   0.439130
#  Druid - Other                              0.388782    0.319270   0.441308
#  Druid - Primordial Druid                   0.582783    0.599447   0.583290
#  Druid - Spell Druid                        0.603934    0.541951   0.648055
#  Hunter - Face Hunter                       0.608579    0.483488   0.678276
#  Hunter - Other                             0.577973    0.573309   0.505125
#  Hunter - Spell Hunter                      0.547000    0.604000   0.462000
#  Mage - Freeze Mage                         0.568456    0.554398   0.539771
#  Mage - No Minion Mage                      0.524694    0.652284   0.574964
#  Mage - Other                               0.515782    0.555605   0.489474
#  Mage - Spell Damage Mage                   0.476621    0.521684   0.506228
#  Paladin - Aggro Paladin                    0.439678    0.380534   0.442314
#  Paladin - Menagerie Paladin                0.597848    0.690930   0.580098
#  Paladin - Other                            0.551989    0.507420   0.548534
#  Paladin - Secret Libram Paladin            0.571999    0.504987   0.619496
#  Paladin - Secret Paladin                   0.582623    0.580031   0.605182
#  Paladin - Silver Hand Paladin              0.517000    0.706000   0.560000
#  Priest - Control Priest                    0.531526    0.465876   0.519552
#  Priest - Corrupt Priest                    0.475771    0.493931   0.515992
#  Priest - Menagerie Priest                  0.544177    0.532515   0.557429
#  Priest - Other                             0.446411    0.443299   0.449463
#  Priest - Rally Priest                      0.494511    0.516260   0.479667
#  Rogue - Miracle Rogue                      0.563330    0.489673   0.570535
#  Rogue - Other                              0.274246    0.348967   0.489809
#  Rogue - Poison Rogue                       0.320372    0.524213   0.589067
#  Rogue - Secret Rogue                       0.665865    0.657589   0.529671
#  Shaman - Aggro Elemental Shaman            0.544136    0.649378   0.655603
#  Shaman - Aggro Shaman                      0.532800    0.661000   0.631400
#  Shaman - Elemental Shaman                  0.696770    0.611563   0.676381
#  Shaman - Other                             0.508651    0.575928   0.627506
#  Warlock - Control Warlock                  0.636347    0.729158   0.548256
#  Warlock - Delete Warlock                   0.493711    0.529702   0.491472
#  Warlock - Other                            0.448784    0.558486   0.448159
#  Warlock - Zoo Warlock                      0.559040    0.543813   0.597862
#  Warrior - Control Warrior                  0.513879    0.473987   0.560436
#  Warrior - Other                            0.535728    0.491462   0.654688
#  Warrior - Rush Warrior                     0.630545    0.504783   0.671736
#  Warrior - Taunt Warrior                    0.375000    0.475000   0.765000
#
#  Versus                                  vs. Shaman  vs. Warlock
#  Deck Name
#  Demonhunter - Big Demon Hunter            0.502253     0.666179
#  Demonhunter - Deathrattle Demon Hunter    0.544850     0.819214
#  Demonhunter - Hybrid Demon Hunter         0.507448     0.682966
#  Demonhunter - Lifesteal Demon Hunter      0.479448     0.610561
#  Demonhunter - Midrange Demon Hunter       0.446527     0.626587
#  Demonhunter - Other                       0.498015     0.634062
#  Druid - Malygos Druid                     0.515045     0.362672
#  Druid - Miracle Druid                     0.256651     0.441829
#  Druid - Other                             0.333112     0.358214
#  Druid - Primordial Druid                  0.489081     0.633122
#  Druid - Spell Druid                       0.505948     0.586502
#  Hunter - Face Hunter                      0.563857     0.686074
#  Hunter - Other                            0.456252     0.624203
#  Hunter - Spell Hunter                     0.456000     0.602000
#  Mage - Freeze Mage                        0.382031     0.431347
#  Mage - No Minion Mage                     0.451861     0.645716
#  Mage - Other                              0.313522     0.525023
#  Mage - Spell Damage Mage                  0.348012     0.497343
#  Paladin - Aggro Paladin                   0.388037     0.448985
#  Paladin - Menagerie Paladin               0.452099     0.656650
#  Paladin - Other                           0.481920     0.531761
#  Paladin - Secret Libram Paladin           0.555231     0.471588
#  Paladin - Secret Paladin                  0.454735     0.601437
#  Paladin - Silver Hand Paladin             0.263000     0.480000
#  Priest - Control Priest                   0.485438     0.289511
#  Priest - Corrupt Priest                   0.430934     0.388715
#  Priest - Menagerie Priest                 0.471200     0.374302
#  Priest - Other                            0.382059     0.317719
#  Priest - Rally Priest                     0.411903     0.303528
#  Rogue - Miracle Rogue                     0.492155     0.575014
#  Rogue - Other                             0.284202     0.468978
#  Rogue - Poison Rogue                      0.433594     0.736629
#  Rogue - Secret Rogue                      0.460086     0.612339
#  Shaman - Aggro Elemental Shaman           0.546370     0.789679
#  Shaman - Aggro Shaman                     0.504600     0.807800
#  Shaman - Elemental Shaman                 0.572756     0.657980
#  Shaman - Other                            0.480278     0.655307
#  Warlock - Control Warlock                 0.421377     0.511645
#  Warlock - Delete Warlock                  0.452610     0.424061
#  Warlock - Other                           0.336937     0.430557
#  Warlock - Zoo Warlock                     0.407888     0.442849
#  Warrior - Control Warrior                 0.518415     0.322524
#  Warrior - Other                           0.515682     0.444942
#  Warrior - Rush Warrior                    0.637085     0.516753
#  Warrior - Taunt Warrior                   0.610000     0.533000  )

# %%
overview
# Out:
#                  Deck Code Match Duration  Turns Turn Duration  \
# 0   Lb2Z0L0DX7ZyyETp2kTNMb    8.8 minutes    9.5    28 seconds
# 1   qsYBtDORz4omc8rMfLrBTh    8.7 minutes    9.0    29 seconds
# 2   SkdknR4pbZjwU2I6TVg7ub    7.9 minutes    9.0    26 seconds
# 3   VaH7QfgJQIPb5StN5W98ee    8.0 minutes    9.0    27 seconds
# 4   70F94fnLqQOKFTGJTpiDzh    8.8 minutes    9.5    28 seconds
# 5   Aobo08Y6K6WAX4hrbdhgwf    8.2 minutes    9.0    27 seconds
# 6   eJsFs1sYYL0Eip2aE3OCWe    8.8 minutes    9.0    29 seconds
# 7   1TqOuo1R1id6wf12owKFjh    8.7 minutes    9.5    27 seconds
# 8   8ooxNX8kwNyrIAGQ4dVwfh    8.6 minutes    9.5    27 seconds
# 9    YQfCYfRgf86MKKZ3Nqr0M    8.3 minutes    9.5    26 seconds
# 10  Uo799iVviiYFKeR2y58m9b    7.9 minutes    8.5    28 seconds
# 11  OWKLz9H0ODxDay4bznLN5g    7.8 minutes    9.0    26 seconds
# 12  Ztw9kHIIhu6z9hiGab2tBe    8.2 minutes    9.0    27 seconds
# 13  Lu1jyDjLUe7GTuEUo6srEh    8.3 minutes    9.0    28 seconds
# 14  nIk6NN24yMYB1j5qY5Qyeg    8.2 minutes    9.0    27 seconds
# 15  fi0EoAykWEPzvelkikzfrg    7.9 minutes    9.0    26 seconds
# 16  v0gwtxmCMWVXGnOYcDy3dg    9.4 minutes   10.0    28 seconds
#
#    Overall Winrate vs. Demon Hunter vs. Druid vs. Hunter vs. Mage vs. Paladin  \
# 0            56.8%            53.7%     47.8%      49.1%    65.1%       60.1%
# 1            62.7%            63.5%     61.6%      57.5%    67.6%       70.2%
# 2            62.0%            63.4%     65.4%      68.3%    64.3%       68.7%
# 3            63.3%            63.3%     53.9%      64.6%    66.1%       61.4%
# 4            57.9%            48.5%     52.0%      60.0%    65.4%       69.7%
# 5            60.1%            63.6%     55.6%      59.6%    62.0%       56.0%
# 6            61.4%            50.0%     67.2%      68.6%    66.7%       54.2%
# 7            65.9%            70.7%     63.6%      65.7%    65.5%       72.5%
# 8            60.9%            51.5%     38.9%      64.3%    64.4%       57.7%
# 9            60.7%            57.1%     50.0%      63.8%    71.9%       53.3%
# 10           56.0%            60.0%     40.5%      49.1%    60.6%       65.5%
# 11           61.2%            63.6%     64.9%      70.6%    73.1%       66.7%
# 12           61.0%            61.3%     58.8%      57.5%    64.4%       55.6%
# 13           62.7%            60.0%     76.0%      59.5%    71.2%       54.5%
# 14           61.3%            60.9%     40.0%      77.8%    67.6%       83.3%
# 15           64.2%            63.6%     57.9%      67.6%    64.9%       61.5%
# 16           64.0%            37.5%     33.3%      62.5%    72.4%       75.0%
#
#    vs. Priest vs. Rogue vs. Shaman vs. Warlock vs. Warrior  Sample Size
# 0       57.1%     56.8%      61.7%       50.0%       61.8%         3700
# 1       60.0%     69.5%      65.6%       51.8%       59.1%         3300
# 2       48.6%     72.3%      66.3%       49.4%       53.1%         1800
# 3       55.4%     66.7%      74.1%       50.9%       67.1%         1000
# 4       55.8%     59.6%      62.3%       48.3%       54.7%         1000
# 5       47.1%     63.2%      66.2%       59.0%       65.6%          770
# 6       39.3%     84.0%      62.0%       58.5%       72.1%          620
# 7       73.4%     70.4%      59.8%       58.2%       63.0%          620
# 8       70.8%     66.7%      68.4%       52.0%       69.8%          610
# 9       62.5%     76.5%      62.0%       50.0%       53.6%          510
# 10      40.5%     80.0%      64.8%       61.3%       34.4%          420
# 11      31.1%     69.2%      60.9%       51.9%       62.5%          380
# 12      43.8%     76.9%      73.5%       65.6%       50.0%          320
# 13      65.8%     80.0%      69.6%       44.0%       41.2%          300
# 14      40.6%     76.5%      64.5%       60.0%       61.1%          220
# 15      68.2%     71.4%      68.6%       42.1%       75.0%          210
# 16      70.4%     71.4%      78.6%       52.0%       63.6%          210

# %%
win_rates.apply(lambda x: x.str.strip('%'))
# Out:
#    Overall Winrate vs. Demon Hunter vs. Druid vs. Hunter vs. Mage vs. Paladin  \
# 0             56.8             53.7      47.8       49.1     65.1        60.1
# 1             62.7             63.5      61.6       57.5     67.6        70.2
# 2             62.0             63.4      65.4       68.3     64.3        68.7
# 3             63.3             63.3      53.9       64.6     66.1        61.4
# 4             57.9             48.5      52.0       60.0     65.4        69.7
# 5             60.1             63.6      55.6       59.6     62.0        56.0
# 6             61.4             50.0      67.2       68.6     66.7        54.2
# 7             65.9             70.7      63.6       65.7     65.5        72.5
# 8             60.9             51.5      38.9       64.3     64.4        57.7
# 9             60.7             57.1      50.0       63.8     71.9        53.3
# 10            56.0             60.0      40.5       49.1     60.6        65.5
# 11            61.2             63.6      64.9       70.6     73.1        66.7
# 12            61.0             61.3      58.8       57.5     64.4        55.6
# 13            62.7             60.0      76.0       59.5     71.2        54.5
# 14            61.3             60.9      40.0       77.8     67.6        83.3
# 15            64.2             63.6      57.9       67.6     64.9        61.5
# 16            64.0             37.5      33.3       62.5     72.4        75.0
#
#    vs. Priest vs. Rogue vs. Shaman vs. Warlock
# 0        57.1      56.8       61.7        50.0
# 1        60.0      69.5       65.6        51.8
# 2        48.6      72.3       66.3        49.4
# 3        55.4      66.7       74.1        50.9
# 4        55.8      59.6       62.3        48.3
# 5        47.1      63.2       66.2        59.0
# 6        39.3      84.0       62.0        58.5
# 7        73.4      70.4       59.8        58.2
# 8        70.8      66.7       68.4        52.0
# 9        62.5      76.5       62.0        50.0
# 10       40.5      80.0       64.8        61.3
# 11       31.1      69.2       60.9        51.9
# 12       43.8      76.9       73.5        65.6
# 13       65.8      80.0       69.6        44.0
# 14       40.6      76.5       64.5        60.0
# 15       68.2      71.4       68.6        42.1
# 16       70.4      71.4       78.6        52.0

# %%
overview.loc[:, 'Overall Winrate':'vs. Warlock']
# Out:
#    Overall Winrate vs. Demon Hunter vs. Druid vs. Hunter vs. Mage vs. Paladin  \
# 0            56.8%            53.7%     47.8%      49.1%    65.1%       60.1%
# 1            62.7%            63.5%     61.6%      57.5%    67.6%       70.2%
# 2            62.0%            63.4%     65.4%      68.3%    64.3%       68.7%
# 3            63.3%            63.3%     53.9%      64.6%    66.1%       61.4%
# 4            57.9%            48.5%     52.0%      60.0%    65.4%       69.7%
# 5            60.1%            63.6%     55.6%      59.6%    62.0%       56.0%
# 6            61.4%            50.0%     67.2%      68.6%    66.7%       54.2%
# 7            65.9%            70.7%     63.6%      65.7%    65.5%       72.5%
# 8            60.9%            51.5%     38.9%      64.3%    64.4%       57.7%
# 9            60.7%            57.1%     50.0%      63.8%    71.9%       53.3%
# 10           56.0%            60.0%     40.5%      49.1%    60.6%       65.5%
# 11           61.2%            63.6%     64.9%      70.6%    73.1%       66.7%
# 12           61.0%            61.3%     58.8%      57.5%    64.4%       55.6%
# 13           62.7%            60.0%     76.0%      59.5%    71.2%       54.5%
# 14           61.3%            60.9%     40.0%      77.8%    67.6%       83.3%
# 15           64.2%            63.6%     57.9%      67.6%    64.9%       61.5%
# 16           64.0%            37.5%     33.3%      62.5%    72.4%       75.0%
#
#    vs. Priest vs. Rogue vs. Shaman vs. Warlock
# 0       57.1%     56.8%      61.7%       50.0%
# 1       60.0%     69.5%      65.6%       51.8%
# 2       48.6%     72.3%      66.3%       49.4%
# 3       55.4%     66.7%      74.1%       50.9%
# 4       55.8%     59.6%      62.3%       48.3%
# 5       47.1%     63.2%      66.2%       59.0%
# 6       39.3%     84.0%      62.0%       58.5%
# 7       73.4%     70.4%      59.8%       58.2%
# 8       70.8%     66.7%      68.4%       52.0%
# 9       62.5%     76.5%      62.0%       50.0%
# 10      40.5%     80.0%      64.8%       61.3%
# 11      31.1%     69.2%      60.9%       51.9%
# 12      43.8%     76.9%      73.5%       65.6%
# 13      65.8%     80.0%      69.6%       44.0%
# 14      40.6%     76.5%      64.5%       60.0%
# 15      68.2%     71.4%      68.6%       42.1%
# 16      70.4%     71.4%      78.6%       52.0%
